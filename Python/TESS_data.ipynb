# %%
! python -m pip install lightkurve --upgrade

# %matplotlib inline
import lightkurve as lk

#search_result = lk.search_lightcurve('TIC 0131799991')
search_result = lk.search_lightcurve('TIC 031381302')
#search_result = lk.search_lightcurve('TIC 129646813') 031381302
search_result
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 1.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.8/994.8 kB 20.5 MB/s eta 0:00:00
# ...
#   Created wheel for fbpca: filename=fbpca-1.0-py3-none-any.whl size=11373 sha256=573bb7bd9024ef1ad217c0baa3bf61628d35261ef8f4d95c1ae087d54165eba4
#   Stored in directory: /Users/rodrigobh/Library/Caches/pip/wheels/04/15/cd/2f622795b09e83471a3be5d2581cd9cf96a6ec7aa78e8deffe
# ...
#   Created wheel for memoization: filename=memoization-0.4.0-py3-none-any.whl size=50453 sha256=f4c579716c878b7a6459d65bc6ed5290262ea5f592f0f18e4db6e9398d17be17
#   Stored in directory: /Users/rodrigobh/Library/Caches/pip/wheels/26/35/02/90618fc7cbf03a335f3cacd59d32b35930bf5a57f3c0d0814c
# ...

# %%
lcf = search_result[1].download()
lcf
# Out:
# <TessLightCurve length=18279 LABEL="TIC 31381302" SECTOR=1 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                     electron / s  ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1325.2961829107635  1.5533911e+03 ...  5.5502318e-02 -3.6218163e-02
#  1325.297571792052  1.5371616e+03 ...  2.8556466e-02 -6.9272302e-02
# 1325.2989606733404  1.5447327e+03 ...  2.8364526e-02 -7.3608346e-02
# 1325.3003495546577  1.5363534e+03 ...  2.7387753e-02 -8.4805682e-02
# 1325.3017384359462  1.5391199e+03 ...  2.0937605e-02 -8.4440470e-02
# 1325.3031273172637  1.5456790e+03 ...  1.9952474e-02 -8.4798798e-02
#  1325.304516198581  1.5300298e+03 ...  2.4047432e-02 -8.9130588e-02
# 1325.3059050799275  1.5452623e+03 ...  2.2795876e-02 -8.5439980e-02
#  1325.307293961245  1.5283928e+03 ...  1.9131673e-02 -8.8032797e-02
# ...

# %%
lcf = search_result[1].download()
p1 = lcf.plot(label='PDCSAP Flux', normalize=True) #[(lcf.time.value > 1341.85) & (lcf.time.value < 1342.025)]
p1.set_ylim([0.977, 1.023])
# Out:
# (0.977, 1.023)

# %%
lcf.to_csv("TIC 031381302.csv")
